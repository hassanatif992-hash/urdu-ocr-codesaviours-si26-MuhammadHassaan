# %% [markdown]
# <a href="https://colab.research.google.com/github/hassanatif992-hash/urdu-ocr-codesaviours-si26-MuhammadHassaan/blob/main/SI26_Week1_MuhammadHassaan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Urdu OCR Project — Week 1
#
# Name: Muhammad Hassaan
#
# Batch: SI-26
#
# Internship: ML / AI Internship Programme
#
# Project: Urdu OCR (Optical Character Recognition)
#
# Phase: Onboarding
#
# Week: 1

# %% [markdown]
# ## What is OCR?
#
# OCR (Optical Character Recognition) is a technology used to convert text from images into machine-readable text. It helps computers recognize printed or handwritten text from scanned documents, books, and images. OCR is widely used for digitizing paper documents.
#
# ## Why is Urdu OCR harder than English OCR?
#
# Urdu OCR is harder because Urdu is written in a cursive style where letters connect together. The shape of letters changes depending on their position in a word. Urdu also contains dots and complex ligatures, making text recognition more difficult.
#
# ## Real-world uses of Urdu OCR
#
# Urdu OCR is useful for digitizing old Urdu books, newspapers, and historical records. It can help offices convert scanned Urdu documents into editable text. It is also useful for extracting text from signboards and printed forms.

# %%
import os

folders = [
    'data/raw/newspaper',
    'data/raw/books',
    'data/raw/signboards',
    'data/raw/synthetic',
    'data/raw/other',
    'notebooks',
    'models',
    'results'
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created: {folder}")

print("Folder structure ready!")
# Out:
# Created: data/raw/newspaper
# Created: data/raw/books
# Created: data/raw/signboards
# Created: data/raw/synthetic
# Created: data/raw/other
# Created: notebooks
# Created: models
# Created: results
# Folder structure ready!

# %%
import csv

labels = [
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120609.png', 'text': 'جمعیت علماء اسلام کا بیان'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120553.png', 'text': 'احسن اقبال کا خطاب'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120539.png', 'text': 'سرگودھا واقعہ'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120521.png', 'text': 'اسحاق ڈار کا رابطہ'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120502.png', 'text': 'رانا ثناء اللہ کا بیان'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120258.png', 'text': 'سیکیورٹی فورسز کا آپریشن'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 120128.png', 'text': 'پاکستان کی خوبصورت تصاویر'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 114450.png', 'text': 'ایرانی انتباہ'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 114345.png', 'text': 'ایران تیل لائسنس'},
    {'image': 'data/raw/newspaper/Screenshot 2026-06-29 114328.png', 'text': 'وفاقی وزیر پیٹرولیم کا بیان'}
]

with open('data/labels.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print("labels.csv created successfully")
# Out:
# labels.csv created successfully

# %%
import os

os.makedirs('/content/Book', exist_ok=True)
os.makedirs('/content/Newspaper', exist_ok=True)
os.makedirs('/content/Signboards', exist_ok=True)
os.makedirs('/content/Others', exist_ok=True)
os.makedirs('/content/Synthetics', exist_ok=True)

print("Folders created")
# Out:
# Folders created

# %%
import csv

labels = [

# Book (10)
{'image': 'Book/Screenshot 2026-07-02 212519.png', 'text': 'کتاب کا صفحہ'},
{'image': 'Book/Screenshot 2026-07-02 212534.png', 'text': 'تعلیم کی اہمیت'},
{'image': 'Book/Screenshot 2026-07-02 212606.png', 'text': 'مطالعہ ضروری ہے'},
{'image': 'Book/Screenshot 2026-07-02 212615.png', 'text': 'علم روشنی ہے'},
{'image': 'Book/Screenshot 2026-07-02 212625.png', 'text': 'اردو مضمون'},
{'image': 'Book/Screenshot 2026-07-02 212657.png', 'text': 'کتاب کا صفحہ'},
{'image': 'Book/Screenshot 2026-07-02 212722.png', 'text': 'مطالعہ کی اہمیت'},
{'image': 'Book/Screenshot 2026-07-02 212814.png', 'text': 'تعلیم اور ترقی'},
{'image': 'Book/Screenshot 2026-07-02 212836.png', 'text': 'علم کا فائدہ'},
{'image': 'Book/Screenshot 2026-07-02 212905.png', 'text': 'کتابی عبارت'},

# Newspaper (20)
{'image': 'Newspaper/888.png', 'text': 'اہم خبر'},
{'image': 'Newspaper/89.png', 'text': 'تازہ خبر'},
{'image': 'Newspaper/895.png', 'text': 'پاکستان کی خبر'},
{'image': 'Newspaper/896.png', 'text': 'اہم بیان'},
{'image': 'Newspaper/897.png', 'text': 'سیاسی خبر'},
{'image': 'Newspaper/898.png', 'text': 'ملکی صورتحال'},
{'image': 'Newspaper/899.png', 'text': 'عوامی خبر'},
{'image': 'Newspaper/9.png', 'text': 'اخباری خبر'},
{'image': 'Newspaper/90.png', 'text': 'نئی خبر'},
{'image': 'Newspaper/900.png', 'text': 'حکومتی بیان'},
{'image': 'Newspaper/901.png', 'text': 'قومی خبر'},
{'image': 'Newspaper/91.png', 'text': 'اہم واقعہ'},
{'image': 'Newspaper/92.png', 'text': 'ملکی حالات'},
{'image': 'Newspaper/93.png', 'text': 'روزنامہ خبر'},
{'image': 'Newspaper/94.png', 'text': 'تازہ ترین خبر'},
{'image': 'Newspaper/95.png', 'text': 'سیاست کی خبر'},
{'image': 'Newspaper/96.png', 'text': 'معاشی خبر'},
{'image': 'Newspaper/97.png', 'text': 'بین الاقوامی خبر'},
{'image': 'Newspaper/98.png', 'text': 'اہم اعلان'},
{'image': 'Newspaper/99.png', 'text': 'بریکنگ نیوز'},

# Others (5)
{'image': 'Others/Screenshot 2026-06-29 113926.png', 'text': 'عام مضمون'},
{'image': 'Others/Screenshot 2026-06-29 120502.png', 'text': 'سیاسی بیان'},
{'image': 'Others/Screenshot 2026-06-29 120521.png', 'text': 'وزارتی خبر'},
{'image': 'Others/Screenshot 2026-06-29 120553.png', 'text': 'تقریر کا خلاصہ'},
{'image': 'Others/Screenshot 2026-06-29 120609.png', 'text': 'اہم خبر'},

# Signboards (5)
{'image': 'Signboards/Screenshot 2026-07-02 212905.png', 'text': 'خوش آمدید'},
{'image': 'Signboards/Screenshot 2026-07-02 220835.png', 'text': 'داخلہ ممنوع'},
{'image': 'Signboards/Screenshot 2026-07-02 220851.png', 'text': 'پارکنگ منع ہے'},
{'image': 'Signboards/Screenshot 2026-07-02 220906.png', 'text': 'براہ کرم انتظار کریں'},
{'image': 'Signboards/Screenshot 2026-07-02 220924.png', 'text': 'صرف عملے کے لیے'},

# Synthetics (5)
{'image': 'synthetics/888.png', 'text': 'پاکستان زندہ باد'},
{'image': 'synthetics/89.png', 'text': 'تعلیم ضروری ہے'},
{'image': 'synthetics/897.png', 'text': 'علم روشنی ہے'},
{'image': 'synthetics/898.png', 'text': 'محنت کامیابی کی کنجی ہے'},
{'image': 'synthetics/899.png', 'text': 'اردو ہماری زبان ہے'}

]

with open('/content/labels.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print("labels.csv created successfully")
# Out:
# labels.csv created successfully

# %%
import os

for folder in ['Book','Newspaper','Others','Signboards','Synthetics']:
    print(folder, len(os.listdir('/content/' + folder)))
# Out:
# Book 22
# Newspaper 21
# Others 21
# Signboards 19
# Synthetics 21

# %%
import os

for folder in ['Book','Newspaper','Others','Signboards','Synthetics']:
    print(folder, len(os.listdir('/content/' + folder)))
# Out:
# Book 22
# Newspaper 21
# Others 21
# Signboards 19
# Synthetics 21

# %%
import os
import csv

labels = []

folders = ['Book', 'Newspaper', 'Others', 'Signboards', 'Synthetics']

for folder in folders:
    folder_path = '/content/' + folder

    for file in os.listdir(folder_path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            labels.append({
                'image': f'{folder}/{file}',
                'text': 'Urdu text here'
            })

with open('/content/labels.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print("labels.csv created successfully")
print("Total labels:", len(labels))
# Out:
# labels.csv created successfully
# Total labels: 102
